# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Car = pd.read_csv("data.csv")
Car.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# # Deskripsi& info dataset Car

# %%
Car.describe(include='number')
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
Car.describe(include='object')
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4787            1110         4764          3048

# %% [markdown]
# # Jumlah Data yang null

# %%
Car.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data = pd.isnull(Car["Market Category"])
Car[data]
# Out:
#          Make     Model  Year                Engine Fuel Type  Engine HP  \
# 87     Nissan     200SX  1996                regular unleaded      115.0
# 88     Nissan     200SX  1996                regular unleaded      115.0
# 91     Nissan     200SX  1997                regular unleaded      115.0
# 92     Nissan     200SX  1997                regular unleaded      115.0
# 93     Nissan     200SX  1998                regular unleaded      115.0
# ...       ...       ...   ...                             ...        ...
# 11794  Subaru        XT  1991                regular unleaded      145.0
# 11809  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11810  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11867     GMC     Yukon  2015  premium unleaded (recommended)      420.0
# 11868     GMC     Yukon  2015  premium unleaded (recommended)      420.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# # Menghapus data Null

# %%
new = Car.dropna(how = 'any')
new.count()
# Out:
# Make                 8084
# Model                8084
# Year                 8084
# Engine Fuel Type     8084
# Engine HP            8084
# Engine Cylinders     8084
# Transmission Type    8084
# Driven_Wheels        8084
# Number of Doors      8084
# Market Category      8084
# Vehicle Size         8084
# Vehicle Style        8084
# highway MPG          8084
# city mpg             8084
# Popularity           8084
# MSRP                 8084
# dtype: int64

# %% [markdown]
# Setelah penghapusan data null,jumlah data yang baru menjadi 8084 yang berarti data yang dihapus 3821 baris

# %% [markdown]
# # Cek dan Hapus Duplicate data

# %%
new.duplicated().sum()
# Out:
# 349

# %%
new.drop_duplicates()
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
newdata = new.drop_duplicates()

# %%
newdata.duplicated().sum()
# Out:
# 0

# %%
newdata.boxplot(by = 'Transmission Type', column = ['Year'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'Year'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['Year'], vert= False)
plt.show()

# %%
percentile25 = newdata['Year'].quantile(0.25)
percentile75 = newdata['Year'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 2010.0
# 2016.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2019.0
# 2007.0

# %%
newdata[newdata['Year'] > upper_limit]
newdata[newdata['Year'] < lower_limit]
# Out:
#           Make   Model  Year             Engine Fuel Type  Engine HP  \
# 17        Audi     100  1992             regular unleaded      172.0
# 19        Audi     100  1992             regular unleaded      172.0
# 21        Audi     100  1992             regular unleaded      172.0
# 22        Audi     100  1993             regular unleaded      172.0
# 23        Audi     100  1993             regular unleaded      172.0
# ...        ...     ...   ...                          ...        ...
# 11889      BMW      Z3  2002  premium unleaded (required)      225.0
# 11903      BMW      Z8  2001  premium unleaded (required)      394.0
# 11904      BMW      Z8  2002  premium unleaded (required)      394.0
# 11905      BMW      Z8  2003  premium unleaded (required)      394.0
# 11913  Lincoln  Zephyr  2006             regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
new_df = newdata[(newdata['Year'] < upper_limit) & (newdata['Year'] > lower_limit)]
new_df.shape
# Out:
# (6415, 16)

# %%
plt.boxplot(new_df['Year'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['MSRP'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'MSRP'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['MSRP'], vert= False)
plt.show()

# %%
percentile25 = newdata['MSRP'].quantile(0.25)
percentile75 = newdata['MSRP'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 26225.0
# 49477.5

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 49480.5
# 26222.0

# %%
newdata[newdata['MSRP'] > upper_limit]
newdata[newdata['MSRP'] < lower_limit]
# Out:
#          Make         Model  Year  Engine Fuel Type  Engine HP  \
# 17       Audi           100  1992  regular unleaded      172.0
# 19       Audi           100  1992  regular unleaded      172.0
# 21       Audi           100  1992  regular unleaded      172.0
# 22       Audi           100  1993  regular unleaded      172.0
# 23       Audi           100  1993  regular unleaded      172.0
# ...       ...           ...   ...               ...        ...
# 11831  Toyota         Yaris  2017  regular unleaded      106.0
# 11832     GMC  Yukon Denali  2000  regular unleaded      255.0
# 11881     BMW            Z3  2000  regular unleaded      193.0
# 11882     BMW            Z3  2000  regular unleaded      193.0
# 11883     BMW            Z3  2000  regular unleaded      170.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
new_df = newdata[newdata['MSRP'] < upper_limit]
new_df.shape
# Out:
# (5801, 16)

# %%
plt.boxplot(new_df['MSRP'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['Engine HP'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'Engine HP'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['Engine HP'], vert= False)
plt.show()

# %%
percentile25 = newdata['Engine HP'].quantile(0.25)
percentile75 = newdata['Engine HP'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 194.0
# 325.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 328.0
# 191.0

# %%
newdata[newdata['Engine HP'] > upper_limit]
newdata[newdata['Engine HP'] < lower_limit]
# Out:
#          Make  Model  Year             Engine Fuel Type  Engine HP  \
# 17       Audi    100  1992             regular unleaded      172.0
# 19       Audi    100  1992             regular unleaded      172.0
# 21       Audi    100  1992             regular unleaded      172.0
# 22       Audi    100  1993             regular unleaded      172.0
# 23       Audi    100  1993             regular unleaded      172.0
# ...       ...    ...   ...                          ...        ...
# 11830  Toyota  Yaris  2017             regular unleaded      106.0
# 11831  Toyota  Yaris  2017             regular unleaded      106.0
# 11883     BMW     Z3  2000             regular unleaded      170.0
# 11885     BMW     Z3  2001  premium unleaded (required)      184.0
# 11888     BMW     Z3  2002  premium unleaded (required)      184.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
new_df = newdata[newdata['Engine HP'] < upper_limit]
new_df.shape
# Out:
# (5861, 16)

# %%
plt.boxplot(new_df['Engine HP'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['Engine Cylinders'],grid = True,vert= False)
# Out:
# <AxesSubplot:title={'center':'Engine Cylinders'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['Engine Cylinders'], vert= False)
plt.show()

# %%
percentile25 = newdata['Engine Cylinders'].quantile(0.25)
percentile75 = newdata['Engine Cylinders'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 4.0
# 6.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 9.0
# 1.0

# %%
newdata[newdata['Engine Cylinders'] > upper_limit]
newdata[newdata['Engine Cylinders'] < lower_limit]
# Out:
#                Make                   Model  Year Engine Fuel Type  Engine HP  \
# 1680  Mercedes-Benz  B-Class Electric Drive  2015         electric      177.0
# 1681  Mercedes-Benz  B-Class Electric Drive  2016         electric      177.0
# 1682  Mercedes-Benz  B-Class Electric Drive  2017         electric      177.0
# 5790            BMW                      i3  2015         electric      170.0
# 5791            BMW                      i3  2016         electric      170.0
# 5792            BMW                      i3  2017         electric      170.0
# 5793            BMW                      i3  2017         electric      170.0
# 9867      Chevrolet                Spark EV  2014         electric      140.0
# 9868      Chevrolet                Spark EV  2014         electric      140.0
# 9869      Chevrolet                Spark EV  2015         electric      140.0
# 9870      Chevrolet                Spark EV  2015         electric      140.0
# ...

# %%
new_df = newdata[(newdata['Engine Cylinders'] < upper_limit) & (newdata['Engine Cylinders'] > lower_limit)]
new_df.shape
# Out:
# (7427, 16)

# %%
plt.boxplot(new_df['Engine Cylinders'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['highway MPG'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'highway MPG'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['highway MPG'], vert= False)
plt.show()

# %%
percentile25 = newdata['highway MPG'].quantile(0.25)
percentile75 = newdata['highway MPG'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 22.0
# 30.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 33.0
# 19.0

# %%
newdata[newdata['highway MPG'] > upper_limit]
newdata[newdata['highway MPG'] < lower_limit]
# Out:
#                 Make         Model  Year             Engine Fuel Type  \
# 169    Mercedes-Benz     300-Class  1991             regular unleaded
# 176    Mercedes-Benz     300-Class  1992             regular unleaded
# 183    Mercedes-Benz     300-Class  1992             regular unleaded
# 193    Mercedes-Benz     300-Class  1993             regular unleaded
# 294          Ferrari           360  2002  premium unleaded (required)
# ...              ...           ...   ...                          ...
# 11363        Bugatti   Veyron 16.4  2008  premium unleaded (required)
# 11364        Bugatti   Veyron 16.4  2009  premium unleaded (required)
# 11394   Aston Martin        Virage  2012  premium unleaded (required)
# 11395   Aston Martin        Virage  2012  premium unleaded (required)
# 11832            GMC  Yukon Denali  2000             regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# ...

# %%
new_df = newdata[(newdata['highway MPG'] < upper_limit) & (newdata['highway MPG'] > lower_limit)]
new_df.shape
# Out:
# (5648, 16)

# %%
plt.boxplot(new_df['highway MPG'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['city mpg'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'city mpg'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['city mpg'], vert= False)
plt.show()

# %%
percentile25 = newdata['city mpg'].quantile(0.25)
percentile75 = newdata['city mpg'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 16.0
# 22.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 25.0
# 13.0

# %%
newdata[newdata['city mpg'] > upper_limit]
newdata[newdata['city mpg'] < lower_limit]
# Out:
#           Make         Model  Year             Engine Fuel Type  Engine HP  \
# 294    Ferrari           360  2002  premium unleaded (required)      400.0
# 295    Ferrari           360  2002  premium unleaded (required)      400.0
# 296    Ferrari           360  2002  premium unleaded (required)      400.0
# 297    Ferrari           360  2002  premium unleaded (required)      400.0
# 298    Ferrari           360  2003  premium unleaded (required)      400.0
# ...        ...           ...   ...                          ...        ...
# 11393    Dodge         Viper  2017  premium unleaded (required)      645.0
# 11832      GMC  Yukon Denali  2000             regular unleaded      255.0
# 11903      BMW            Z8  2001  premium unleaded (required)      394.0
# 11904      BMW            Z8  2002  premium unleaded (required)      394.0
# 11905      BMW            Z8  2003  premium unleaded (required)      394.0
#
# ...

# %%
new_df = newdata[(newdata['city mpg'] < upper_limit) & (newdata['city mpg'] > lower_limit)]
new_df.shape
# Out:
# (5830, 16)

# %%
plt.boxplot(new_df['city mpg'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['Popularity'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'Popularity'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['Popularity'], vert= False)
plt.show()

# %%
percentile25 = newdata['Popularity'].quantile(0.25)
percentile75 = newdata['Popularity'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 520.0
# 2009.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2012.0
# 517.0

# %%
newdata[newdata['Popularity'] > upper_limit]
newdata[newdata['Popularity'] < lower_limit]
# Out:
#              Make   Model  Year                Engine Fuel Type  Engine HP  \
# 194    Mitsubishi  3000GT  1997                regular unleaded      218.0
# 195    Mitsubishi  3000GT  1997                regular unleaded      161.0
# 196    Mitsubishi  3000GT  1997                regular unleaded      320.0
# 197    Mitsubishi  3000GT  1998                regular unleaded      320.0
# 198    Mitsubishi  3000GT  1998                regular unleaded      161.0
# ...           ...     ...   ...                             ...        ...
# 11909       Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910       Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911       Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912       Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913     Lincoln  Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
new_df = newdata[(newdata['Popularity'] < upper_limit) & (newdata['Popularity'] > lower_limit)]
new_df.shape
# Out:
# (4103, 16)

# %%
plt.boxplot(new_df['Popularity'], vert= False)
plt.show()

# %%
newdata.boxplot(by = 'Transmission Type', column = ['Number of Doors'],grid = True, vert= False)
# Out:
# <AxesSubplot:title={'center':'Number of Doors'}, xlabel='Transmission Type'>

# %%
plt.boxplot(newdata['Number of Doors'], vert= False)
plt.show()

# %%
percentile25 = newdata['Number of Doors'].quantile(0.25)
percentile75 = newdata['Number of Doors'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 2.0
# 4.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 7.0
# -1.0

# %%
newdata[newdata['Number of Doors'] > upper_limit]
newdata[newdata['Number of Doors'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
import seaborn as sn
sn.scatterplot(x='Popularity',y='MSRP',hue='MSRP',data=newdata)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='MSRP'>

# %%
import scipy.stats

# %%
scipy.stats.pearsonr(newdata['Popularity'], newdata['MSRP'])
# Out:
# (-0.054614541052716244, 1.5390545449094117e-06)

# %% [markdown]
# Direction : Negative , Strength : Strong, Shape Linear

# %%
sn.scatterplot(x='Engine Cylinders',y='Engine HP',hue='Engine HP',data=newdata)
# Out:
# <AxesSubplot:xlabel='Engine Cylinders', ylabel='Engine HP'>

# %%
scipy.stats.pearsonr(newdata['Engine Cylinders'], newdata['Engine HP'])
# Out:
# (0.8111381418801079, 0.0)

# %% [markdown]
# Direction : Positif
# Strength : Strong
# Shape :Linear`

# %%
sn.scatterplot(x='Engine HP',y='highway MPG',hue='highway MPG',data=newdata)
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='highway MPG'>

# %%
scipy.stats.pearsonr(newdata['Engine HP'], newdata['highway MPG'])
# Out:
# (-0.46832750900051107, 0.0)

# %% [markdown]
# Direction : Negative, Strength : Strong, Shape : Linear

# %%
sn.scatterplot(x='Engine HP',y='city mpg',hue='city mpg',data=newdata)
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='city mpg'>

# %%
from scipy.stats import spearmanr

# %%
rho, p = spearmanr(newdata['Engine HP'], newdata['city mpg'])
print(rho)
# Out:
# -0.6790997271225451

# %%
print(p)
# Out:
# 0.0

# %% [markdown]
# Direction : Negative, Strength : Strong, Shape: Curve

# %%
sn.scatterplot(x='Engine HP',y='MSRP',hue='MSRP',data=newdata)
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='MSRP'>

# %%
rho, p = spearmanr(newdata['Engine HP'], newdata['MSRP'])
print(rho)
# Out:
# 0.8215274744306447

# %%
print(p)
# Out:
# 0.0

# %% [markdown]
# Drirection : Positif, Strength : Strong , Shape Curve

# %%
best_popularity = newdata.nlargest(20,'Popularity')
best_popularity
# Out:
#       Make           Model  Year          Engine Fuel Type  Engine HP  \
# 1469  Ford          Aspire  1995          regular unleaded       63.0
# 1471  Ford          Aspire  1995          regular unleaded       63.0
# 1472  Ford          Aspire  1996          regular unleaded       63.0
# 1473  Ford          Aspire  1996          regular unleaded       63.0
# 1474  Ford          Aspire  1997          regular unleaded       63.0
# 1475  Ford          Aspire  1997          regular unleaded       63.0
# 2095  Ford    C-Max Hybrid  2015          regular unleaded      188.0
# 2096  Ford    C-Max Hybrid  2015          regular unleaded      188.0
# 2097  Ford    C-Max Hybrid  2016          regular unleaded      188.0
# 2098  Ford    C-Max Hybrid  2016          regular unleaded      188.0
# 2099  Ford    C-Max Hybrid  2017          regular unleaded      188.0
# 2100  Ford    C-Max Hybrid  2017          regular unleaded      188.0
# ...

# %%
best_MSRP = new.nlargest(20,'MSRP')
best_MSRP
# Out:
#                 Make                   Model  Year  \
# 11362        Bugatti             Veyron 16.4  2008
# 11364        Bugatti             Veyron 16.4  2009
# 8486     Lamborghini                Reventon  2008
# 11363        Bugatti             Veyron 16.4  2008
# 6351         Maybach               Landaulet  2012
# 6350         Maybach               Landaulet  2011
# 4024         Ferrari                    Enzo  2003
# 1622     Lamborghini               Aventador  2014
# 1626     Lamborghini               Aventador  2015
# 1629     Lamborghini               Aventador  2016
# 698          Maybach                      62  2010
# 1623     Lamborghini               Aventador  2014
# 1627     Lamborghini               Aventador  2015
# 9683   Mercedes-Benz             SLR McLaren  2008
# 9684   Mercedes-Benz             SLR McLaren  2009
# 7564     Rolls-Royce                 Phantom  2016
# 7558     Rolls-Royce  Phantom Drophead Coupe  2016
# ...

# %%
best_Engine_HP = new.nlargest(20,'Engine HP')
best_Engine_HP
# Out:
#               Make           Model  Year                Engine Fuel Type  \
# 11362      Bugatti     Veyron 16.4  2008     premium unleaded (required)
# 11363      Bugatti     Veyron 16.4  2008     premium unleaded (required)
# 11364      Bugatti     Veyron 16.4  2009     premium unleaded (required)
# 1629   Lamborghini       Aventador  2016     premium unleaded (required)
# 1630   Lamborghini       Aventador  2016     premium unleaded (required)
# 4644       Ferrari  F12 Berlinetta  2013     premium unleaded (required)
# 4645       Ferrari  F12 Berlinetta  2014     premium unleaded (required)
# 4646       Ferrari  F12 Berlinetta  2015     premium unleaded (required)
# 1622   Lamborghini       Aventador  2014     premium unleaded (required)
# 1623   Lamborghini       Aventador  2014     premium unleaded (required)
# 1626   Lamborghini       Aventador  2015     premium unleaded (required)
# 1627   Lamborghini       Aventador  2015     premium unleaded (required)
# ...

# %%
sns.pairplot(newdata)
